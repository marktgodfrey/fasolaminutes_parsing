# %%
import re
import util
import spacy
import csv


def check_ner(text):
    nlp = spacy.load("en_core_web_sm") # loading pre-trained English Model
    processed_text = nlp(text) # process text
    for ent in processed_text.ent:
        if ent.label_ == "Person":
            return True
    return False

# %% [markdown]
# **Spacy Implementation**

# %%
import spacy

def clean_ner(text):
    ner = spacy.load("en_core_web_sm")
    processed_text = ner(text)
    if processed_text.ents:
        return processed_text.ents[0].text, True
    else:
        return text, False 
    
name = 'Reverend Brian Sam Williams'

verified = clean_ner(name)
print(verified)
if verified[1]==True:
    print("pass")
# Out:
# ('Brian Sam Williams', True)
# pass

# %%
import spacy

def clean_ner(text):
    ner = spacy.load("en_core_web_sm")
    names = text.split()
    
    if len(names) >= 3: # under assumption len of 2 is only first and last name
        processed_text = ner(names[0])
        for ent in processed_text.ents:
            if ent.label_ == "PERSON":
                return ent.text, True
    return " ".join(names[1:]), False

# name = 'Reverand Brian Sam Williams'
# verified = clean_ner(name)
# print(verified)

# if verified[1]:
#     print("pass")

name = 'Brian Sam Willaims'

bad_words = [
    'Chairman',
    'Chairperson',
    'Chairwoman',
    'Chairmen',
    'Chair',
    'Chairlady',
    'Chairpersons',
    'Chairs',
    'Co-Chair',
    'Co-Chairs',
    'Co-Chairmen',
    'Co-Chairperson',
    'Co-chair',
    'Co-chairs',
    'Singing',
    'Secretary',
    'Secretaries',
    'Treasurer',
    'Treasurers',
    'Director',
    'Committee',
    'Committees',
    'Convention',
    'Sacred',
    'Musical',
    'Methodist',
    'Baptist',
    'Episcopal',
    'Anglican',
    'Mennonite',
    'Catholic',
    'Pastor',
    'Minister',
    'Ministry',
    'National',
    'Library',
    'Shape',
    'Note',
    'State',
    'Sacra',
    'United',
    'Memorial',
    'Alabama',
    'Mississippi',
    'Arrangement',
    'Arrangements',
    'Arranging',
    'College',
    'University',
    'Courthouse',
    'Meetinghouse',
    'Meeting House'
    'Friends',
    'Seminary',
    'Cemetary',
    'SHMHA',
    'Seek',
    'President',
    'Vice',
    'After',
    'Then',
    'Academy',
    'Officers',
    'Chaplain',
    'Fasola',
    'FaSoLa',
    'Southern',
    'Western',
    'Northwestern',
    'North',
    'Pacific',
    'Northern',
    'International',
    'Center',
    'African',
    'American',
    'School',
    'Elementary',
    'Highway',
    'Outgoing',
    'Recreation',
    'City',
    'County',
    'Avenue',
    'Public',
    'Publishing',
    'Primitive',
    'Mountain',
    'Annual',
    'Department',
    'Presbyterian',
    'Conference',
    'Railroad',
    'Society',
    'Historical',
    'Association',
    'Professor',
    'Associate',
    'Municipal',
    'Building',
    'Labor',
    'County',
    'Line',
    'Elder',
    'Resolutions',
    'Father',
    'Moderator']

for word in bad_words:
    example = word+" "+name
    print(example," : ",clean_ner(example)[0])
# Out:
# Chairman Brian Sam Willaims  :  Brian Sam Willaims
# Chairperson Brian Sam Willaims  :  Brian Sam Willaims
# Chairwoman Brian Sam Willaims  :  Brian Sam Willaims
# Chairmen Brian Sam Willaims  :  Brian Sam Willaims
# Chair Brian Sam Willaims  :  Brian Sam Willaims
# Chairlady Brian Sam Willaims  :  Chairlady
# Chairpersons Brian Sam Willaims  :  Brian Sam Willaims
# Chairs Brian Sam Willaims  :  Brian Sam Willaims
# Co-Chair Brian Sam Willaims  :  Brian Sam Willaims
# Co-Chairs Brian Sam Willaims  :  Brian Sam Willaims
# Northwestern Brian Sam Willaims  :  Brian Sam Willaims
# North Brian Sam Willaims  :  Brian Sam Willaims
# Pacific Brian Sam Willaims  :  Brian Sam Willaims
# Northern Brian Sam Willaims  :  Brian Sam Willaims
# International Brian Sam Willaims  :  Brian Sam Willaims
# Center Brian Sam Willaims  :  Brian Sam Willaims
# African Brian Sam Willaims  :  Brian Sam Willaims
# American Brian Sam Willaims  :  Brian Sam Willaims
# School Brian Sam Willaims  :  Brian Sam Willaims
# Elementary Brian Sam Willaims  :  Brian Sam Willaims
# Highway Brian Sam Willaims  :  Brian Sam Willaims
# Outgoing Brian Sam Willaims  :  Brian Sam Willaims
# Recreation Brian Sam Willaims  :  Brian Sam Willaims
# City Brian Sam Willaims  :  Brian Sam Willaims
# County Brian Sam Willaims  :  Brian Sam Willaims
# Avenue Brian Sam Willaims  :  Brian Sam Willaims
# Public Brian Sam Willaims  :  Brian Sam Willaims
# Publishing Brian Sam Willaims  :  Brian Sam Willaims
# Primitive Brian Sam Willaims  :  Brian Sam Willaims
# Mountain Brian Sam Willaims  :  Brian Sam Willaims
# Annual Brian Sam Willaims  :  Brian Sam Willaims
# Department Brian Sam Willaims  :  Brian Sam Willaims
# Presbyterian Brian Sam Willaims  :  Brian Sam Willaims
# Conference Brian Sam Willaims  :  Brian Sam Willaims
# Railroad Brian Sam Willaims  :  Brian Sam Willaims
# Society Brian Sam Willaims  :  Brian Sam Willaims
# Historical Brian Sam Willaims  :  Brian Sam Willaims
# Association Brian Sam Willaims  :  Brian Sam Willaims
# Professor Brian Sam Willaims  :  Brian Sam Willaims
# Associate Brian Sam Willaims  :  Brian Sam Willaims
# Municipal Brian Sam Willaims  :  Brian Sam Willaims
# Building Brian Sam Willaims  :  Brian Sam Willaims
# Labor Brian Sam Willaims  :  Brian Sam Willaims
# County Brian Sam Willaims  :  Brian Sam Willaims
# Line Brian Sam Willaims  :  Brian Sam Willaims
# Elder Brian Sam Willaims  :  Brian Sam Willaims
# Resolutions Brian Sam Willaims  :  Brian Sam Willaims
# Father Brian Sam Willaims  :  Brian Sam Willaims
# Moderator Brian Sam Willaims  :  Brian Sam Willaims

# %% [markdown]
# **FuzzyWuzzy Implementation**

# %%
from fuzzywuzzy import fuzz


print('Jesse P. Karlsberg', 'J.P Karlsberg')
print('fuzz.ratio: ',fuzz.ratio('Jesse P. Karlsberg', 'J.P Karlsberg')) #
print('fuzz.WRatio: ',fuzz.WRatio('Jesse P. Karlsberg', 'J.P Karlsberg')) # handles lower and upper cases and some other parameters too

print()
print('Billy Williams,', 'Doyle Williams:')
print('fuzz.ratio: ',fuzz.ratio('Billy Williams', 'Doyle Williams')) #
print('fuzz.WRatio: ',fuzz.WRatio('Billy Williams', 'Doyle Williams')) # handles lower and upper cases and some other parameters too

print()
print('Billy Williams,', 'Corene White')
print('fuzz.ratio: ',fuzz.ratio('Billy Williams', 'Corene White')) #
print('fuzz.WRatio: ',fuzz.WRatio('Billy Williams', 'Corene White')) # handles lower and upper cases and some other parameters too
# Out:
# Jesse P. Karlsberg J.P Karlsberg
# fuzz.ratio:  77
# fuzz.WRatio:  87
#
# Billy Williams, Doyle Williams:
# fuzz.ratio:  71
# fuzz.WRatio:  71
#
# Billy Williams, Corene White
# fuzz.ratio:  23
# fuzz.WRatio:  23
